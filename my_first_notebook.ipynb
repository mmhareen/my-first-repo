# %% [markdown]
# What is the difference between hardware and software? Give one example of each.
#
# In short, hardware is the physical part of the computer which we can touch, software is which we cannot touch ie the instructions or programs which tell hardware what is to be done.
# Examples:
# Hardware : Computer Monitor, Mouse, Keyboard, etc
# Software: Python, Java, Microsoft Office Tools etc
